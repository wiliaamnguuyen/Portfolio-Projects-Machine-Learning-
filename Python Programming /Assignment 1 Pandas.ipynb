# %% [markdown]
# ## Assignment 1 - Pandas
#
# ### Part 1
# The columns are organized as the number of Summer games, Summer mdeals, number of Winter games, Winter medals, total number of medals.
#
# ### Exploring dataset to create function

# %%
import pandas as pd

# %%
pd.read_csv("olympics.csv")
# Out:
#                                                 0         1     2     3     4  \
# 0                                             NaN  # Summer  01 !  02 !  03 !
# 1                               Afghanistan (AFG)        13     0     0     2
# 2                                   Algeria (ALG)        12     5     2     8
# 3                                 Argentina (ARG)        23    18    24    28
# 4                                   Armenia (ARM)         5     1     2     9
# 5                         Australasia (ANZ) [ANZ]         2     3     4     5
# 6                       Australia (AUS) [AUS] [Z]        25   139   152   177
# 7                                   Austria (AUT)        26    18    33    35
# 8                                Azerbaijan (AZE)         5     6     5    15
# 9                                   Bahamas (BAH)        15     5     2     5
# 10                                  Bahrain (BRN)         8     0     0     1
# ...

# %%
pd.read_csv('olympics.csv',index_col=0)
# Out:
#                                                      1     2     3     4  \
# 0
# NaN                                           # Summer  01 !  02 !  03 !
# Afghanistan (AFG)                                   13     0     0     2
# Algeria (ALG)                                       12     5     2     8
# Argentina (ARG)                                     23    18    24    28
# Armenia (ARM)                                        5     1     2     9
# Australasia (ANZ) [ANZ]                              2     3     4     5
# Australia (AUS) [AUS] [Z]                           25   139   152   177
# Austria (AUT)                                       26    18    33    35
# Azerbaijan (AZE)                                     5     6     5    15
# Bahamas (BAH)                                       15     5     2     5
# Bahrain (BRN)                                        8     0     0     1
# Barbados (BAR) [BAR]                                11     0     0     1
# ...

# %%
pd.read_csv('olympics.csv',index_col=0,skiprows=1)
# Out:
#                                               # Summer  01 !  02 !  03 !  \
# Afghanistan (AFG)                                   13     0     0     2
# Algeria (ALG)                                       12     5     2     8
# Argentina (ARG)                                     23    18    24    28
# Armenia (ARM)                                        5     1     2     9
# Australasia (ANZ) [ANZ]                              2     3     4     5
# Australia (AUS) [AUS] [Z]                           25   139   152   177
# Austria (AUT)                                       26    18    33    35
# Azerbaijan (AZE)                                     5     6     5    15
# Bahamas (BAH)                                       15     5     2     5
# Bahrain (BRN)                                        8     0     0     1
# Barbados (BAR) [BAR]                                11     0     0     1
# Belarus (BLR)                                        5    12    24    39
# ...

# %%
pd.read_csv('olympics.csv',skiprows=1)
# Out:
#                                        Unnamed: 0  # Summer  01 !  02 !  03 !  \
# 0                               Afghanistan (AFG)        13     0     0     2
# 1                                   Algeria (ALG)        12     5     2     8
# 2                                 Argentina (ARG)        23    18    24    28
# 3                                   Armenia (ARM)         5     1     2     9
# 4                         Australasia (ANZ) [ANZ]         2     3     4     5
# 5                       Australia (AUS) [AUS] [Z]        25   139   152   177
# 6                                   Austria (AUT)        26    18    33    35
# 7                                Azerbaijan (AZE)         5     6     5    15
# 8                                   Bahamas (BAH)        15     5     2     5
# 9                                   Bahrain (BRN)         8     0     0     1
# 10                           Barbados (BAR) [BAR]        11     0     0     1
# ...

# %%
df = pd.read_csv('olympics.csv',skiprows=1)
first_row = df.iloc[0,0]
first_row
# Out:
# 'Afghanistan\xc2\xa0(AFG)'

# %%
df.head()
# Out:
#                 Unnamed: 0  # Summer  01 !  02 !  03 !  Total  # Winter  \
# 0        Afghanistan (AFG)        13     0     0     2      2         0
# 1            Algeria (ALG)        12     5     2     8     15         3
# 2          Argentina (ARG)        23    18    24    28     70        18
# 3            Armenia (ARM)         5     1     2     9     12         6
# 4  Australasia (ANZ) [ANZ]         2     3     4     5     12         0
#
#    01 !.1  02 !.1  03 !.1  Total.1  # Games  01 !.2  02 !.2  03 !.2  \
# 0       0       0       0        0       13       0       0       2
# 1       0       0       0        0       15       5       2       8
# 2       0       0       0        0       41      18      24      28
# 3       0       0       0        0       11       1       2       9
# 4       0       0       0        0        2       3       4       5
#
#    Combined total
# 0               2
# 1              15
# 2              70
# 3              12
# 4              12

# %%
first_row.split('\xc2\xa0')
# Out:
# ['Afghanistan', '(AFG)']

# %%
first_row.split('\xc2\xa0')[0]
# Out:
# 'Afghanistan'

# %%
df['Unnamed: 0'] = df['Unnamed: 0'].apply(lambda x: x.split('\xc2\xa0')[0])
df.head(5)
# Out:
#     Unnamed: 0  # Summer  01 !  02 !  03 !  Total  # Winter  01 !.1  02 !.1  \
# 0  Afghanistan        13     0     0     2      2         0       0       0
# 1      Algeria        12     5     2     8     15         3       0       0
# 2    Argentina        23    18    24    28     70        18       0       0
# 3      Armenia         5     1     2     9     12         6       0       0
# 4  Australasia         2     3     4     5     12         0       0       0
#
#    03 !.1  Total.1  # Games  01 !.2  02 !.2  03 !.2  Combined total
# 0       0        0       13       0       0       2               2
# 1       0        0       15       5       2       8              15
# 2       0        0       41      18      24      28              70
# 3       0        0       11       1       2       9              12
# 4       0        0        2       3       4       5              12

# %%
#How do I set the first column as the index? 
df.set_index(df['Unnamed: 0'].values,inplace=True)
df.head()
# Out:
#               Unnamed: 0  # Summer  01 !  02 !  03 !  Total  # Winter  01 !.1  \
# Afghanistan  Afghanistan        13     0     0     2      2         0       0
# Algeria          Algeria        12     5     2     8     15         3       0
# Argentina      Argentina        23    18    24    28     70        18       0
# Armenia          Armenia         5     1     2     9     12         6       0
# Australasia  Australasia         2     3     4     5     12         0       0
#
#              02 !.1  03 !.1  Total.1  # Games  01 !.2  02 !.2  03 !.2  \
# Afghanistan       0       0        0       13       0       0       2
# Algeria           0       0        0       15       5       2       8
# Argentina         0       0        0       41      18      24      28
# Armenia           0       0        0       11       1       2       9
# Australasia       0       0        0        2       3       4       5
#
#              Combined total
# Afghanistan               2
# ...

# %%
del df['Unnamed: 0']

# %%
df.head()
# Out:
#              # Summer  01 !  02 !  03 !  Total  # Winter  01 !.1  02 !.1  \
# Afghanistan        13     0     0     2      2         0       0       0
# Algeria            12     5     2     8     15         3       0       0
# Argentina          23    18    24    28     70        18       0       0
# Armenia             5     1     2     9     12         6       0       0
# Australasia         2     3     4     5     12         0       0       0
#
#              03 !.1  Total.1  # Games  01 !.2  02 !.2  03 !.2  Combined total
# Afghanistan       0        0       13       0       0       2               2
# Algeria           0        0       15       5       2       8              15
# Argentina         0        0       41      18      24      28              70
# Armenia           0        0       11       1       2       9              12
# Australasia       0        0        2       3       4       5              12

# %%
df.head()
# Out:
#    # Summer  01 !  02 !  03 !  Total  # Winter  01 !.1  02 !.1  03 !.1  \
# 0        13     0     0     2      2         0       0       0       0
# 1        12     5     2     8     15         3       0       0       0
# 2        23    18    24    28     70        18       0       0       0
# 3         5     1     2     9     12         6       0       0       0
# 4         2     3     4     5     12         0       0       0       0
#
#    Total.1  # Games  01 !.2  02 !.2  03 !.2  Combined total
# 0        0       13       0       0       2               2
# 1        0       15       5       2       8              15
# 2        0       41      18      24      28              70
# 3        0       11       1       2       9              12
# 4        0        2       3       4       5              12

# %%
def load_data(csv_file):
    """
    Create a dataframe with following data cleanup to make this file
    readble.
        - Create a function load_data to read CSV file and convert 
        CSV data to dataframe.
        - Skip first row
        - Rename column containing 01, 02 and 03 to Gold, Silver 
        and Bronze
        - Split country name and country code and add country name 
        as data frame index
        - Remove extra unnecessary characters from country name.
        - Drop the column Totals
        - Return dataframe.
    """
    
    df = pd.read_csv(csv_file,index_col=0,skiprows=1)
    renamed_col = {'01 !': 'Gold',
                    '02 !': 'Silver',
                    '03 !': 'Bronze',
                    '01 !.1': 'Gold',
                    '02 !.1': 'Silver',
                    '03 !.1': 'Bronze',
                    '01 !.2': 'Gold',
                    '02 !.2': 'Silver',
                    '03 !.2': 'Bronze',
                   'Total.1': 'Total'}
    
    #Renaming the columns
    df.rename(columns = renamed_col,inplace=True)
    
    #Renaming column 0 to make it more neater
    df.iloc[:,0] = df.iloc[:,0].apply(lambda x:x.split('\xc2\xa0')[0])
    
    #Setting first column as the index
    df.set_index(df['Unnamed: 0'].values,inplace=True)
    
    #Dropping the first column since it has now been set by the index
    del df['Unnamed: 0']
    
    #Removing totals column
    del df['Total']
    
    return df

# %% [markdown]
# ### Getting First Country Details from Dataframe
# Using the above function to get first country details by:
# - Creating a function to return results for first country.

# %%
load_data('olympics.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-23fe5694f595> in <module>()
# ----> 1 load_data('olympics.csv')
#
# <ipython-input-61-d23eb99ff2ba> in load_data(csv_file)
#      33
#      34     #Renaming column 0 to make it more neater
# ---> 35     df.iloc[:,0] = df.iloc[:,0].apply(lambda x:x.split('\xc2\xa0')[0])
#      36
#      37     #Setting first column as the index
#
# /anaconda3/lib/python2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-61-d23eb99ff2ba> in <lambda>(x)
#      33
# ...
